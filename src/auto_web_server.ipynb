# %%
import pandas as pd
import json
import random
from pathlib import Path

# %%
# !pip install selenium webdriver-manager

# %%
file_paths = [
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_Epi.394.csv",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_ExeMes.394.csv",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_NasMes.333.csv",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PGC.356.csv",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PS.378.csv",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_Epi.394.csv",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_NasMes.390.csv",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_PS.376.csv",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_aPS.383.csv"
]

st_txt_paths = [
  "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_Epi.394.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_ExeMes.394.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_NasMes.333.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PGC.356.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PS.378.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_Epi.394.st.txt",
   "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_NasMes.390.st.txt",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_PS.376.st.txt",
    "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_aPS.383.st.txt"
]


basenames = [ Path(p).name.strip(".csv") for p in file_paths ]
email = "ali.chemkhi@curie.fr"
orientation_cut="0.01"

# %%
import time
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait


# === CONFIG ===
CSV_FILE_PATH = "/Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.2/2D_gast_grouped_v0.2/2D_gast_grouped_v0.2_BMP_Epi.462.csv"  # Replace this
WAIT_TIME = 90  # Time to wait for results to load (adjust based on dataset size)

# === SETUP SELENIUM DRIVER ===
options = Options()
options.headless = False  # Set to True if you want to run in the background
prefs = {"download.prompt_for_download": False}
options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

for path,path_st,name in zip(file_paths,st_txt_paths,basenames):
    print(name,":",path)
    try:
        # STEP 1: Open MIIC

        driver.get("https://miic.curie.fr/workbench.php")
        time.sleep(2)

        # --- analysis name 
        upload_input = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[1]/div/div[2]/div/input")
        upload_input.send_keys(name)
        time.sleep(1)

        # --- email
        upload_input = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[1]/div/div[3]/div/input")
        upload_input.send_keys(email)
        time.sleep(1)

        # --- csv path 
        upload_input = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[1]/div/div[4]/div[1]/input[2]")
        upload_input.send_keys(path)
        time.sleep(1)

        # --- st path
        upload_input = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[2]/div[4]/div/div[3]/div[1]/input[1]")
        upload_input.send_keys(path_st)
        time.sleep(1)
        print("added st path ")


        
        # --- skeleton cut
        # Wait until the radio button is present and clickable
        radio_button = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[2]/div[5]/div/div[1]/div/input[1]")
        # Scroll it into view
        driver.execute_script("arguments[0].scrollIntoView(true);", radio_button)
        time.sleep(0.5)  # Give browser time to render
        driver.execute_script("arguments[0].click();", radio_button)
        # Confirm selection
        print("Selected:", radio_button.is_selected())
  
        # --- orientation cut
        upload_input = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[2]/div[6]/div/div/div/input")
        # Set the value directly using JS
        driver.execute_script("arguments[0].value = arguments[1];", upload_input, orientation_cut)
        time.sleep(1)

        
            
        # STEP 4: Launch MIIC
        print("Launching MIIC job...")
        submit_button = driver.find_element(By.XPATH, "/html/body/div[2]/form/div[2]/div[8]/div/div/input")
        submit_button.click()
        time.sleep(3)


        result_link_element = driver.find_element(By.XPATH, "/html/body/div[2]/div/div[2]/div[3]/div[2]/div/table/tbody/tr[1]/td[2]/a")
        result_link = result_link_element.get_attribute("href")
        print(f"----> Result link: {result_link}")



    except : 
        print("Done.")
        #driver.quit()
# Out:
# 2D_gast_grouped_v0.3_BMP_Epi.394 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_Epi.394.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=qpzCijP4D7AooRVG5Lo6
# 2D_gast_grouped_v0.3_BMP_ExeMes.394 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_ExeMes.394.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=ntfkdn6JUb9E5OcxdZt8
# 2D_gast_grouped_v0.3_BMP_NasMes.333 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_NasMes.333.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=db6C4ntD1oZ34HYz2I6C
# ...

# %% [raw]
# 2D_gast_grouped_v0.3_BMP_Epi.394 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_Epi.394.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=qpzCijP4D7AooRVG5Lo6
# 2D_gast_grouped_v0.3_BMP_ExeMes.394 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_ExeMes.394.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=ntfkdn6JUb9E5OcxdZt8
# 2D_gast_grouped_v0.3_BMP_NasMes.333 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_NasMes.333.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=db6C4ntD1oZ34HYz2I6C
# 2D_gast_grouped_v0.3_BMP_PGC.356 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PGC.356.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=5CNcwswCHXzKFHLkDSan
# 2D_gast_grouped_v0.3_BMP_PS.378 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PS.378.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=w2xaYtanQWPn6DGKLtfO
# 2D_gast_grouped_v0.3_WNT_Epi.394 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_Epi.394.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=vPs3schoWAm56HuFu6xP
# 2D_gast_grouped_v0.3_WNT_NasMes.390 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_NasMes.390.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=Krqu47P6PJrd7zJp3WH6
# 2D_gast_grouped_v0.3_WNT_PS.376 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_PS.376.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=iGRqSJRABU9lh7NbHAFf
# 2D_gast_grouped_v0.3_WNT_aPS.383 : /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_aPS.383.csv
# added st path
# Selected: True
# Launching MIIC job...
# ----> Result link: https://miic.curie.fr/status.php?id=BtaXTxayNcYdLBw5rAIy

# %% [markdown]
#        BMP MM468 Neg WNT
#   aPS      2     0   0 155
#   Epi     31     0   0  71
#   ExeMes  65     0   0   0
#   NasMes 160     0   0 118
#   PGC    116     0   0   0
#   PS      96     0   0  86
#
# [1] "filtered time colomn. keeping only t36 and t37"
# [1] "time"
#
#          BMP MM468 Neg WNT
#   aPS      2     0   0 105
#   Epi     19     0   0  43
#   ExeMes  47     0   0   0
#   NasMes 112     0   0  75
#   PGC     78     0   0   0
#   PS      63     0   0  55
#
#
# # ---------------- BMP
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_Epi.394.csv
# Result link: https://miic.curie.fr/status.php?id=P1u7si4DdCZD8SIPVsLQ
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_ExeMes.394.csv
# Result link: https://miic.curie.fr/status.php?id=dBg8eJ0oeTkaR0T5LXU3
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_NasMes.333.csv
# Result link: https://miic.curie.fr/status.php?id=e0shuEcliJd3hk05FBqV
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PGC.356.csv
# Result link: https://miic.curie.fr/status.php?id=esDErrO6xJ81Et4AihZ7
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_BMP_PS.378.csv
# Result link: https://miic.curie.fr/status.php?id=LNXmfyotm0bCejwug8XX
#
# # ---------------- WNT
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_Epi.394.csv
# Result link: https://miic.curie.fr/status.php?id=LsEgc5osfGims5sBTGhR
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_NasMes.390.csv
# Result link: https://miic.curie.fr/status.php?id=SEkIBmo7YeGuuzFXvZfs
#
#
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_PS.376.csv
# Opening MIIC website...
# Name job
# email adress
# Done.
# /Users/alichemkhi/Desktop/myProjects/2D_gast/output/v0.3/2D_gast_grouped_v0.3/2D_gast_grouped_v0.3_WNT_aPS.383.csv
# Opening MIIC website...
# Done.
